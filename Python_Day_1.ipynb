# %% [markdown]
# <a href="https://colab.research.google.com/github/psunny5/Sunny_QA-Automation_Genzeon_2023/blob/main/Python_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#data types

#integer type
a=2
b=4+5j

#float
c=5.2

#text type
str1="hi"

#sequence type
my_list=[1,2,3,4]

#tuple type
my_tup=(4,5,6,7)

#Set type
my_set={1,2,3,4}

#mapping type
my_dict={'name':'Genzeon'}

#boolean type
x=True
y=False

#Binary type
x=b"Hello"

#nonet type
x=None

# %%
#type conversion
#explicit conversion & implicit conversion

#explicit conversion
a=3
b=4.0
c=float(a)
d=int(b)
print(d)

#implicit conversion
b=3
c=4.0
c1=b+c
print(c1)

a=3
c2=str(a)  #Strings can't be converted to int
print(c2)
# Out:
# 4
# 7.0
# 3

# %%
#operators

#Arithmetic operators
a=10
b=5

print(a+b)
print(a-b)
print(a/b)
print(a//b)
print(a*b)
print(a**b)
print(a%b)

#comparison operators
a==b
a<=b
a>=b
a>>b
a<b
a!=b

#Assignment operators
c=a+b
c+=a
c-=a

#Logical operators
x=True
y=False
print("x and y is",x and y)
print("x and y is",x or y)
print("x NOT is",not y)

#bitwise operators
a=13
b=14
print(a&b)#and
print(a^b)#xor
print(a|b)#OR
print(-a)#NOT
print(a>>2)#Right shift
print(a<<2)#Left shift
# Out:
# 15
# 5
# 2.0
# 2
# 50
# 100000
# 0
# x and y is False
# x and y is True
# x NOT is True
